# %% [markdown]
# # Credit
#
# ---
#
#
# #  <font color='Orange' size="33" type="Arial Black">ML-</font><font  color='black' background-color= 'black' size='33' >O</Font><font color='Orange' size='33'>ne</font> <font color="grey" size='3'> Powered by AIEdX</font>
#
# ![alt text](https://storage.googleapis.com/aiedx-public/MLONE-ART2.jpg)
#
#
# ---
#
# ><font color=orange size=5>***Welcome to MLOne*** </font>
#
# Visit [AIEdX](https://aiedx.com) to learn more.
#
# Visit [AIEDX-Github](https://github.com/AIEdX/MLOne) to view MLOne github page.

# %% [markdown]
# #  Lesson 2: Introduction to NLP
# > ## Notebook 1: NLP Process Demo
#
#
#
#
# </font>
#
# > [Subscibe Here](https://aiedx.com/mlone)
#
# > ![Subscribe Here](https://storage.googleapis.com/aiedx-public/MLOne%20Classroom.jpg)

# %%
pip install allennlp
# Out:
# ...
#      |████████████████████████████████| 689 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 124 kB 50.0 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 36.4 MB/s
# ...
#      |████████████████████████████████| 2.5 MB 64.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 57.8 MB/s
# ...
#      |████████████████████████████████| 259 kB 56.8 MB/s
# ...
#      |████████████████████████████████| 12.1 MB 218 kB/s
# ...
#      |████████████████████████████████| 105 kB 42.8 MB/s
# ...
#      |████████████████████████████████| 131 kB 61.2 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 22.3 MB 16 kB/s
# ...
#      |████████████████████████████████| 167 kB 59.4 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 52.3 MB/s
# ...
#      |████████████████████████████████| 79 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 138 kB 47.5 MB/s
# ...
#      |████████████████████████████████| 75 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 127 kB 71.3 MB/s
# ...

# %%
allennlp.
